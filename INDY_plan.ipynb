# %% [markdown]
# <a href="https://colab.research.google.com/github/genright02/INDY_plan/blob/main/INDY_plan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

worksheet = gc.open('INDY_plan').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print(rows)

# Convert to a DataFrame and render.
import pandas as pd
pd.DataFrame.from_records(rows)
# Out:
# [['Time', 'PLACE', 'ADDRESS', 'RATING', 'WEBSITE', 'WALKING TIME FROM PREVIOUS SPOT', 'TYPE'], ['9 A.M.', 'Garden Table', '342 Massachusets Ave', '4.5', 'https://thegardentable.com/massave', '0', 'Breakfast'], ['10 A.M.', 'Mass Ave ', 'Massachusets Ave', '4.7', 'https://www.visitindy.com/indianapolis-mass-ave-arts-district', '0', 'Shopping'], ['Recommendations', 'Global Gifts', '446 Massachusetts Ave', '4.7', 'https://www.globalgiftsft.com', '4', 'Shopping'], ['', 'Sage Boutique', '431 Massachusetts Ave', '4', 'https://downtownindy.org/go/sage-boutique', '1', 'Shopping'], ['', 'Silver in the City', '434 Massachusetts Ave', '4.7', 'https://www.silverinthecity.com', '1', 'Shopping'], ['11:30 A.M.', 'University Park & Indiana War Memorial', '307 N Meridian St', '4.5', 'https://www.indianawarmemorials.org', '7', 'Park/Memorial'], ['12:30 P.M.', 'Canal Walk', 'Canal Walk, Indianapolis', '4.5', 'https://www.visitindy.com/indianapolis-canal-walk', '12', 'Park'], ['1:30 P.M.', 'Fresco Italia
# ...
